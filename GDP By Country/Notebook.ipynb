# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('GDP_2005-2025.csv')

# %%
df.head()

# %%
df.columns

# %%
df.info()

# %%
for col in df.columns:
    df[col].fillna(df[col].mean(), inplace=True)
