# %%
# !pip install pandas numpy matplotlib

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
df = pd.read_csv('each_ball_records.csv')

# %%
df.head()
# Out:
#    match_no  ballnumber  inningno  over outcome           batter  \
# 0         1           1         1   0.1       0     Devon Conway
# 1         1           2         1   0.2     1lb     Devon Conway
# 2         1           3         1   0.3       0  Ruturaj Gaikwad
# 3         1           4         1   0.4       1  Ruturaj Gaikwad
# 4         1           5         1   0.5       0     Devon Conway
#
#            bowler                                     comment  score
# 0  Mohammed Shami     Mohammed Shami to Devon Conway, no run,      0
# 1  Mohammed Shami  Mohammed Shami to Devon Conway, 1 leg bye,      1
# 2  Mohammed Shami  Mohammed Shami to Ruturaj Gaikwad, no run,      0
# 3  Mohammed Shami   Mohammed Shami to Ruturaj Gaikwad, 1 run,      1
# 4  Mohammed Shami     Mohammed Shami to Devon Conway, no run,      0

# %%
df.columns
# Out:
# Index(['match_no', 'ballnumber', 'inningno', 'over', 'outcome', 'batter',
#        'bowler', 'comment', 'score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17863 entries, 0 to 17862
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   match_no    17863 non-null  int64
#  1   ballnumber  17863 non-null  int64
#  2   inningno    17863 non-null  int64
#  3   over        17863 non-null  float64
#  4   outcome     17863 non-null  object
#  5   batter      17863 non-null  object
#  6   bowler      17863 non-null  object
#  7   comment     17863 non-null  object
#  8   score       17863 non-null  int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.2+ MB

# %%
type(df["outcome"])
# Out:
# pandas.core.series.Series

# %%
new_columns_name = [] 
for i in df.columns:
    new_columns_name.append(i.capitalize())

# %%
new_columns_name
# Out:
# ['Match_no',
#  'Ballnumber',
#  'Inningno',
#  'Over',
#  'Outcome',
#  'Batter',
#  'Bowler',
#  'Comment',
#  'Score']

# %%
df.columns = new_columns_name
df.head()
# Out:
#    Match_no  Ballnumber  Inningno  Over Outcome           Batter  \
# 0         1           1         1   0.1       0     Devon Conway
# 1         1           2         1   0.2     1lb     Devon Conway
# 2         1           3         1   0.3       0  Ruturaj Gaikwad
# 3         1           4         1   0.4       1  Ruturaj Gaikwad
# 4         1           5         1   0.5       0     Devon Conway
#
#            Bowler                                     Comment  Score
# 0  Mohammed Shami     Mohammed Shami to Devon Conway, no run,      0
# 1  Mohammed Shami  Mohammed Shami to Devon Conway, 1 leg bye,      1
# 2  Mohammed Shami  Mohammed Shami to Ruturaj Gaikwad, no run,      0
# 3  Mohammed Shami   Mohammed Shami to Ruturaj Gaikwad, 1 run,      1
# 4  Mohammed Shami     Mohammed Shami to Devon Conway, no run,      0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# Match_no      0
# Ballnumber    0
# Inningno      0
# Over          0
# Outcome       0
# Batter        0
# Bowler        0
# Comment       0
# Score         0
# dtype: int64

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_8092\3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df["Ballnumber"].nunique()
# Out:
# 136

# %%
df.head(12)
# Out:
#     Match_no  Ballnumber  Inningno  Over Outcome           Batter  \
# 0          1           1         1   0.1       0     Devon Conway
# 1          1           2         1   0.2     1lb     Devon Conway
# 2          1           3         1   0.3       0  Ruturaj Gaikwad
# 3          1           4         1   0.4       1  Ruturaj Gaikwad
# 4          1           5         1   0.5       0     Devon Conway
# 5          1           6         1   0.6       0     Devon Conway
# 6          1           7         1   1.1       4  Ruturaj Gaikwad
# 7          1           8         1   1.2       0  Ruturaj Gaikwad
# 8          1           9         1   1.3       4  Ruturaj Gaikwad
# 9          1          10         1   1.4       1  Ruturaj Gaikwad
# 10         1          11         1   1.5       1     Devon Conway
# 11         1          12         1   1.6       1  Ruturaj Gaikwad
#
#             Bowler                                     Comment  Score
# ...

# %%
type(df["Outcome"])
# Out:
# pandas.core.series.Series

# %%
df.drop_duplicates(inplace=True)

# %%
list(df["Outcome"].unique())
# Out:
# ['0',
#  '1lb',
#  '1',
#  '4',
#  'w',
#  '6',
#  '1nb',
#  '4lb',
#  '2',
#  '1b',
#  '1wd',
#  '2nb',
#  '5nb',
#  '7nb',
#  '3',
#  '5wd',
#  '4b',
#  '2wd',
#  '5',
#  '3wd',
#  '2lb',
#  '3nb',
#  '2b']

# %%
df.to_csv('ipl_2023_cleaned.csv', index=False)

# %%
df.head(12)
# Out:
#     Match_no  Ballnumber  Inningno  Over Outcome           Batter  \
# 0          1           1         1   0.1       0     Devon Conway
# 1          1           2         1   0.2     1lb     Devon Conway
# 2          1           3         1   0.3       0  Ruturaj Gaikwad
# 3          1           4         1   0.4       1  Ruturaj Gaikwad
# 4          1           5         1   0.5       0     Devon Conway
# 5          1           6         1   0.6       0     Devon Conway
# 6          1           7         1   1.1       4  Ruturaj Gaikwad
# 7          1           8         1   1.2       0  Ruturaj Gaikwad
# 8          1           9         1   1.3       4  Ruturaj Gaikwad
# 9          1          10         1   1.4       1  Ruturaj Gaikwad
# 10         1          11         1   1.5       1     Devon Conway
# 11         1          12         1   1.6       1  Ruturaj Gaikwad
#
#             Bowler                                     Comment  Score  runs
# ...

# %%
text_cols = ["Outcome", "Comment", "Batter", "Bowler"]
for col in text_cols:
    df[col] = df[col].astype(str).str.strip()

# %%
df.head(2)
# Out:
#    Match_no  Ballnumber  Inningno  Over Outcome        Batter          Bowler  \
# 0         1           1         1   0.1       0  devon conway  Mohammed Shami
# 1         1           2         1   0.2     1lb  devon conway  Mohammed Shami
#
#                                       Comment  Score  runs
# 0     mohammed shami to devon conway, no run,      0     0
# 1  mohammed shami to devon conway, 1 leg bye,      1     0

# %%
# same goes with numeric columns
num_col = ["Match_no","Ballnumber", "Inningno", "Over", "Score", "runs"]
for col in num_col:
    df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0).astype(int)

# %%
df.to_csv('ipl_2023_cleaned_new.csv', index=False)
