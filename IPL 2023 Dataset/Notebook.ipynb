# %%
# !pip install pandas numpy matplotlib
# Out:
# ...
#   Using cached pandas-2.3.2-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.10.6-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.0-cp313-cp313-win_amd64.whl.metadata (113 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached pandas-2.3.2-cp313-cp313-win_amd64.whl (11.0 MB)
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    --------- ------------------------------ 3.1/12.8 MB 16.5 MB/s eta 0:00:01
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
df = pd.read_csv('each_ball_records.csv')

# %%
df.head()
# Out:
#    match_no  ballnumber  inningno  over outcome           batter  \
# 0         1           1         1   0.1       0     Devon Conway
# 1         1           2         1   0.2     1lb     Devon Conway
# 2         1           3         1   0.3       0  Ruturaj Gaikwad
# 3         1           4         1   0.4       1  Ruturaj Gaikwad
# 4         1           5         1   0.5       0     Devon Conway
#
#            bowler                                     comment  score
# 0  Mohammed Shami     Mohammed Shami to Devon Conway, no run,      0
# 1  Mohammed Shami  Mohammed Shami to Devon Conway, 1 leg bye,      1
# 2  Mohammed Shami  Mohammed Shami to Ruturaj Gaikwad, no run,      0
# 3  Mohammed Shami   Mohammed Shami to Ruturaj Gaikwad, 1 run,      1
# 4  Mohammed Shami     Mohammed Shami to Devon Conway, no run,      0

# %%
df.columns
# Out:
# Index(['match_no', 'ballnumber', 'inningno', 'over', 'outcome', 'batter',
#        'bowler', 'comment', 'score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17863 entries, 0 to 17862
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   match_no    17863 non-null  int64
#  1   ballnumber  17863 non-null  int64
#  2   inningno    17863 non-null  int64
#  3   over        17863 non-null  float64
#  4   outcome     17863 non-null  object
#  5   batter      17863 non-null  object
#  6   bowler      17863 non-null  object
#  7   comment     17863 non-null  object
#  8   score       17863 non-null  int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.2+ MB

# %%
type(df["outcome"])
# Out:
# pandas.core.series.Series

# %%
new_columns_name = [] 
for i in df.columns:
    new_columns_name.append(i.capitalize())

# %%
new_columns_name
# Out:
# ['Match_no',
#  'Ballnumber',
#  'Inningno',
#  'Over',
#  'Outcome',
#  'Batter',
#  'Bowler',
#  'Comment',
#  'Score']

# %%
df.columns = new_columns_name
df.head()
# Out:
#    Match_no  Ballnumber  Inningno  Over Outcome           Batter  \
# 0         1           1         1   0.1       0     Devon Conway
# 1         1           2         1   0.2     1lb     Devon Conway
# 2         1           3         1   0.3       0  Ruturaj Gaikwad
# 3         1           4         1   0.4       1  Ruturaj Gaikwad
# 4         1           5         1   0.5       0     Devon Conway
#
#            Bowler                                     Comment  Score
# 0  Mohammed Shami     Mohammed Shami to Devon Conway, no run,      0
# 1  Mohammed Shami  Mohammed Shami to Devon Conway, 1 leg bye,      1
# 2  Mohammed Shami  Mohammed Shami to Ruturaj Gaikwad, no run,      0
# 3  Mohammed Shami   Mohammed Shami to Ruturaj Gaikwad, 1 run,      1
# 4  Mohammed Shami     Mohammed Shami to Devon Conway, no run,      0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# Match_no      0
# Ballnumber    0
# Inningno      0
# Over          0
# Outcome       0
# Batter        0
# Bowler        0
# Comment       0
# Score         0
# dtype: int64

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_7468\3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df["Ballnumber"].nunique()
# Out:
# 136

# %%
df.head(12)
# Out:
#     Match_no  Ballnumber  Inningno  Over Outcome           Batter  \
# 0          1           1         1   0.1       0     Devon Conway
# 1          1           2         1   0.2     1lb     Devon Conway
# 2          1           3         1   0.3       0  Ruturaj Gaikwad
# 3          1           4         1   0.4       1  Ruturaj Gaikwad
# 4          1           5         1   0.5       0     Devon Conway
# 5          1           6         1   0.6       0     Devon Conway
# 6          1           7         1   1.1       4  Ruturaj Gaikwad
# 7          1           8         1   1.2       0  Ruturaj Gaikwad
# 8          1           9         1   1.3       4  Ruturaj Gaikwad
# 9          1          10         1   1.4       1  Ruturaj Gaikwad
# 10         1          11         1   1.5       1     Devon Conway
# 11         1          12         1   1.6       1  Ruturaj Gaikwad
#
#             Bowler                                     Comment  Score
# ...

# %%
type(df["Outcome"])
# Out:
# pandas.core.series.Series

# %%
# df["Outcome"] = df["Outcome"].replace("1lb", 1).astype(int)

# %%
# df["Outcome"] = pd.to_numeric(df["Outcome"], errors='coerce')

# %%
# df["Outcome"] = df["Outcome"].fillna(0).astype(int)

# %%
# df.head()

# %%
df.drop_duplicates(inplace=True)

# %%
df["runs"] = pd.to_numeric(df["outcome"], errors="coerce").fillna(0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Study Material\PYTHON\PANDAS\IPL 2023 Dataset\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'outcome'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ...

# %%
df["runs"] = pd.to_numeric(df["outcome"], errors="coerce").fillna(0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Study Material\PYTHON\PANDAS\IPL 2023 Dataset\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'outcome'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ...
