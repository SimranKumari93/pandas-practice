# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('monthly.csv')

# %%
df.head()
# Out:
#      Month  Price
# 0  1997-01   3.45
# 1  1997-02   2.15
# 2  1997-03   1.89
# 3  1997-04   2.03
# 4  1997-05   2.25

# %%
df.shape
# Out:
# (345, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   345 non-null    object
#  1   Price   345 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.5+ KB

# %%
df.columns
# Out:
# Index(['Month', 'Price'], dtype='object')

# %%
df.dropna(thresh=len(df.columns) - 3, inplace=True)

# %%
df.replace({True: 1, False: 0, 'True': 1, 'False': 0}, inplace=True)

# %%
df.replace(r'^\s*$', pd.NA, regex=True, inplace=True)

# %% [markdown]
# <!-- This data seems to be clean -->
