# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\study material\python\pandas\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\study material\python\pandas\.venv\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\study material\python\pandas\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\study material\python\pandas\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\study material\python\pandas\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\study material\python\pandas\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
df = pd.read_csv('users.csv')

# %%
df.head()
# Out:
#       user_id                      email first_name last_name   age  gender  \
# 0  user_00001   figueroajohn@example.org      Erica     Garza  43.0    Male
# 1  user_00002      blakeerik@example.com     Joshua   Bernard  38.0    Male
# 2  user_00003        smiller@example.net    Barbara  Williams  32.0  Female
# 3  user_00004  mitchellclark@example.com    Chelsea  Ferguson  11.0    Male
# 4  user_00005      richard13@example.net      Jason    Foster  21.0  Female
#
#   country state_province                city subscription_plan  \
# 0     USA  Massachusetts  North Jefferyhaven             Basic
# 1     USA          Texas      North Noahstad          Premium+
# 2     USA       Michigan          Traciebury          Standard
# 3     USA           Ohio          South Noah          Standard
# 4     USA        Arizona         West Donald          Standard
#
#   subscription_start_date  is_active  monthly_spend primary_device  \
# 0              2024-04-08       True          36.06         Laptop
# 1              2024-05-24       True          14.59        Desktop
# 2              2023-09-22      False          11.71        Desktop
# 3              2024-08-21       True          28.56         Laptop
# 4              2024-10-28       True           9.54        Desktop
#
#    household_size                  created_at
# 0             1.0  2023-04-01 14:40:50.540242
# 1             2.0  2024-10-10 15:39:11.030515
# 2             3.0  2024-06-29 14:27:49.560875
# 3             2.0  2023-04-11 01:01:59.614841
# 4             6.0  2025-04-12 19:59:30.137806

# %%
df.columns
# Out:
# Index(['user_id', 'email', 'first_name', 'last_name', 'age', 'gender',
#        'country', 'state_province', 'city', 'subscription_plan',
#        'subscription_start_date', 'is_active', 'monthly_spend',
#        'primary_device', 'household_size', 'created_at'],
#       dtype='object')

# %%
df.shape
# Out:
# (10300, 16)

# %%
df.replace(r'^\s*$', pd.NA, regex=True, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(thresh=len(df.columns) - 3, inplace=True)

# %%
df.replace({True: 1, False: 0, 'True': 1, 'False': 0}, inplace=True)
# Out:
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\2852048486.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({True: 1, False: 0, 'True': 1, 'False': 0}, inplace=True)

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col].fillna(df[col].mode()[0], inplace=True)
    else:
        df[col].fillna(df[col].median(), inplace=True)
# Out:
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\1842323058.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\1842323058.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\1842323058.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\1842323058.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\1842323058.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\1842323058.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\1842323058.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\Simran Kumari\AppData\Local\Temp\ipykernel_20832\1842323058.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.round(2)
# Out:
#          user_id                       email first_name last_name   age  \
# 0     user_00001    figueroajohn@example.org      Erica     Garza  43.0
# 1     user_00002       blakeerik@example.com     Joshua   Bernard  38.0
# 2     user_00003         smiller@example.net    Barbara  Williams  32.0
# 3     user_00004   mitchellclark@example.com    Chelsea  Ferguson  11.0
# 4     user_00005       richard13@example.net      Jason    Foster  21.0
# ...          ...                         ...        ...       ...   ...
# 9995  user_09996  jessicaestrada@example.org     Joshua  Harrison  46.0
# 9996  user_09997      lewisroger@example.com     Steven  Thompson  35.0
# 9997  user_09998          lisa14@example.com      Nancy  Galloway  33.0
# 9998  user_09999          kscott@example.org     Rhonda  Mckenzie  30.0
# 9999  user_10000         kevin71@example.org     Marcus   Morales  40.0
#
#       gender country    state_province                city subscription_plan  \
# 0       Male     USA     Massachusetts  North Jefferyhaven             Basic
# 1       Male     USA             Texas      North Noahstad          Premium+
# 2     Female     USA          Michigan          Traciebury          Standard
# 3       Male     USA              Ohio          South Noah          Standard
# 4     Female     USA           Arizona         West Donald          Standard
# ...      ...     ...               ...                 ...               ...
# 9995  Female     USA             Texas            Luistown          Premium+
# 9996    Male     USA           Florida          Brownmouth             Basic
# 9997    Male     USA    North Carolina            Tinaland          Standard
# 9998  Female  Canada  British Columbia   Port Jeanetteview           Premium
# 9999    Male  Canada           Ontario           Reyestown           Premium
#
#      subscription_start_date  is_active  monthly_spend primary_device  \
# 0                 2024-04-08          1          36.06         Laptop
# 1                 2024-05-24          1          14.59        Desktop
# 2                 2023-09-22          0          11.71        Desktop
# 3                 2024-08-21          1          28.56         Laptop
# 4                 2024-10-28          1           9.54        Desktop
# ...                      ...        ...            ...            ...
# 9995              2024-07-09          1           5.13        Desktop
# 9996              2025-07-17          1          13.82         Laptop
# 9997              2023-10-04          1          12.10       Smart TV
# 9998              2025-05-12          1          14.73        Desktop
# 9999              2022-09-26          1          17.95        Desktop
#
#       household_size                  created_at
# 0                1.0  2023-04-01 14:40:50.540242
# 1                2.0  2024-10-10 15:39:11.030515
# 2                3.0  2024-06-29 14:27:49.560875
# 3                2.0  2023-04-11 01:01:59.614841
# 4                6.0  2025-04-12 19:59:30.137806
# ...              ...                         ...
# 9995             2.0  2022-10-13 00:19:59.664856
# 9996             1.0  2022-08-25 19:58:08.326565
# 9997             2.0  2025-05-28 10:02:35.235233
# 9998             1.0  2024-07-14 10:36:03.719715
# 9999             1.0  2024-06-03 22:53:10.930630
#
# [9997 rows x 16 columns]

# %%
df.to_csv("users_cleaned.csv", index=False)
