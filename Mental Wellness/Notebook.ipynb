# %%
# !pip install pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pd.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.__version__
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv('mental_wellness.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %%
df.head()

# %%
df.columns

# %%
df.info()

# %%
type(df['Age'])

# %%
df.columns

# %%
new_column_names = []
for i iin df.columns:
    new_column_names.append(i.strip().lower().replace(' ', '_').replace('(', '').replace(')', ''))

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()

# %%
df["user_id"].nunique()

# %%
df["user_id"] = df["user_id"].astype(int)

# %%
df = pd.to_datetime(df['date'], errors='coerce')

# %%
df = pd.to_csv('mental_wellness_cleaned.csv', index=False)
